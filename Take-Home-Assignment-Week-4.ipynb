# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\rhuth\Desktop\Sem - 1\Data Science BootCamp 2023 Fall\Week - 4\boston_housing_data.csv")
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %% [markdown]
# ### 1. Create a line plot of ZN and INDUS in the housing data.
#
# ####    a. For ZN, use a solid green line. For INDUS, use a blue dashed line.
# ####	b. Change the figure size to a width of 12 and height of 8.
# ####	c. Change the style sheet to something you find https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html.

# %%
plt.plot(data["ZN"], label = "ZN", color = "green", linestyle = "-")
plt.plot(data["INDUS"], label = "INDUS", color = "blue", linestyle = "--")

plt.xlabel("Data pts")
plt.ylabel("Values")
plt.title("line Plt of ZN and Indus")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.plot(data["ZN"], label = "ZN", color = "green", linestyle = "-")
plt.plot(data["INDUS"], label = "INDUS", color = "blue", linestyle = "--")

plt.xlabel("Data pts")
plt.ylabel("Values")
plt.title("line Plt of ZN and Indus")
plt.legend()
plt.show()

# %%
plt.style.use('dark_background')
plt.figure(figsize=(12, 8))
plt.plot(data["ZN"], label = "ZN", color = "green", linestyle = "-")
plt.plot(data["INDUS"], label = "INDUS", color = "blue", linestyle = "--")

plt.xlabel("Data pts")
plt.ylabel("Values")
plt.title("line Plt of ZN and Indus")
plt.legend()
plt.show()

# %% [markdown]
# ### 2. Create a bar chart using col1 and col2 of dummy data.
#
# ####	a. Give the plot a large title of your choosing.
# ####	b. Move the legend to the lower-left corner.
# ####	c. Do the same thing but with horizontal bars.
# ####	d. Move the legend to the upper-right corner.

# %%
data = {
    'col1': ['A', 'B', 'C', 'D', 'E'],
    'col2': [10, 15, 7, 12, 9]
}

df = pd.DataFrame(data)

col1_values = df['col1']
col2_values = df['col2']

plt.bar(col1_values, col2_values, color='blue')

plt.xlabel('Letters')
plt.ylabel('Numbers')
plt.title('Bar Chart of Letters and Numbers')

plt.show()

# %%
data = {
    'col1': ['A', 'B', 'C', 'D', 'E'],
    'col2': [10, 15, 7, 12, 9]
}

df = pd.DataFrame(data)

col1_values = df['col1']
col2_values = df['col2']

plt.bar(col1_values, col2_values, color='blue')

plt.xlabel('Letters')
plt.ylabel('Numbers')
plt.title('Bar Chart of Letters and Numbers')
plt.legend(['col1'], loc = 'lower left')
plt.show()

# %%
data = {
    'col1': ['A', 'B', 'C', 'D', 'E'],
    'col2': [10, 15, 7, 12, 9]
}

df = pd.DataFrame(data)

col1_values = df['col1']
col2_values = df['col2']

plt.barh(col1_values, col2_values, color='blue')

plt.xlabel('Letters')
plt.ylabel('Numbers')
plt.title('Bar Chart of Letters and Numbers')
plt.legend(['col2'], loc = 'lower left')
plt.show()

# %%
data = {
    'col1': ['A', 'B', 'C', 'D', 'E'],
    'col2': [10, 15, 7, 12, 9]
}

df = pd.DataFrame(data)

col1_values = df['col1']
col2_values = df['col2']

plt.barh(col1_values, col2_values, color='blue')

plt.xlabel('Letters')
plt.ylabel('Numbers')
plt.title('Bar Chart of Letters and Numbers')
plt.legend(['col2'], loc = 'upper right')
plt.show()

# %% [markdown]
# ### 3. Create a histogram with pandas for using MEDV in the housing data.
#
# ####	a. Set the bins to 20

# %%
plt.hist(data["MEDV"], bins=20, color='blue', edgecolor='black')

# Add labels and a title
plt.xlabel("MEDV")
plt.ylabel("Frequency")
plt.title("Histogram of MEDV with 20 Bins")

# Show the plot
plt.show()

# %% [markdown]
# ### 4. Create a scatter plot of two heatmap entries that appear to have a very positive correlation.

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(8, 6))
sns.scatterplot(x=data["NOX"], y=data["TAX"])

plt.xlabel("NOX")
plt.ylabel("TAX")
plt.title("Scatter Plot of Variables NOX and TAX")

plt.show()

# %% [markdown]
# ### 5. Create a scatter plot of two heatmap entries that appear to have negative correlation.

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(8, 6))
sns.scatterplot(x=data["NOX"], y=data["RM"])

plt.xlabel("NOX")
plt.ylabel("RM")
plt.title("Scatter Plot of Variables NOX and RM")

plt.show()
